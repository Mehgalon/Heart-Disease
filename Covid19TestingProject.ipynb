# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehgalon/Heart-Disease/blob/master/Covid19TestingProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/COVID-19_Daily_Testing - COVID-19_Daily_Testing.csv')

# %%
Cases.head(15)()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b6753625df8f> in <module>()
# ----> 1 Cases.head(15)()
#
# NameError: name 'Cases' is not defined

# %%
df.tail(15)
# Out:
#           Date  ... People Not-Positive - Unknown Race/Ethnicity
# 74  03/26/2020  ...                                          571
# 75  03/25/2020  ...                                          511
# 76  04/27/2020  ...                                        1,353
# 77    03-12-20  ...                                           53
# 78  04/21/2020  ...                                        1,008
# 79  03/16/2020  ...                                          226
# 80  04/24/2020  ...                                        1,358
# 81    03-04-20  ...                                           20
# 82    03-08-20  ...                                           18
# 83  03/18/2020  ...                                          247
# 84  04/26/2020  ...                                          588
# 85  03/17/2020  ...                                          236
# 86    05-05-20  ...                                        1,958
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Tests', 'Cases', 'People Not-Positive - Total',
#        'People Tested - Age 0-17', 'People Tested - Age 18-29',
#        'People Tested - Age 30-39', 'People Tested - Age 40-49',
#        'People Tested - Age 50-59', 'People Tested - Age 60-69',
#        'People Tested - Age 70-79', 'People Tested - Age 80+',
#        'People Tested - Age Unknown', 'People Tested - Female',
#        'People Tested - Male', 'People Tested - Gender Unknown',
#        'People Tested - Latinx', 'People Tested - Asian Non-Latinx',
#        'People Tested - Black Non-Latinx', 'People Tested - White Non-Latinx',
#        'People Tested - Other Race Non-Latinx',
#        'People Tested - Unknown Race/Ethnicity', 'People Positive - Age 0-17',
#        'People Positive - Age 18-29', 'People Positive - Age 30-30',
#        'People Positive - Age 40-49', 'People Positive - Age 50-59',
#        'People Positive - Age 60-69', 'People Positive - Age 70-79',
# ...

# %%
df.describe()
# Out:
#        People Tested - Age 0-17  ...  People Not-Positive - Other Race Non-Latinx
# count                 89.000000  ...                                    89.000000
# mean                 111.011236  ...                                    60.078652
# std                  109.086652  ...                                    44.783627
# min                    0.000000  ...                                     0.000000
# 25%                   25.000000  ...                                    25.000000
# 50%                   63.000000  ...                                    52.000000
# 75%                  194.000000  ...                                    98.000000
# max                  397.000000  ...                                   169.000000
#
# [8 rows x 44 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 59 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Date                                          88 non-null     object
#  1   Day                                           88 non-null     object
#  2   Tests                                         89 non-null     object
#  3   Cases                                         89 non-null     object
#  4   People Not-Positive - Total                   89 non-null     object
#  5   People Tested - Age 0-17                      89 non-null     int64
#  6   People Tested - Age 18-29                     89 non-null     object
#  7   People Tested - Age 30-39                     89 non-null     object
#  8   People Tested - Age 40-49                     89 non-null     int64
# ...

# %%
df['Cases'] = pd.to_numeric(df['Cases'].str.replace(',', ''))

# %%
sns.reset_orig
sns.distplot(df['Cases'],  bins=40)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
correlation_matrix = df.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)# Too many variables for heat map. Need to create new dataframe and delete columns.

# %%
#OBSERVATIONS - Data needed some cleaning, objects had to be converted into integers. Mondays, Tuesdays and Fridays see the most activity. Most of the cases fall under 0.001

# %%
#Prepare Data For Machine Learning Model

# %%
from sklearn.linear_model import LinearRegression

# %%
linReg = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-830ed5e65d76> in <module>()
# ----> 1 x.head()
#
# NameError: name 'x' is not defined

# %%
y.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-17b2b1f6e15b> in <module>()
# ----> 1 y.head()
#
# NameError: name 'y' is not defined

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-bc5f1a0adac8> in <module>()
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
y.shape

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3307faafe6e1> in <module>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(X,y)
#
# NameError: name 'X' is not defined

# %%
linReg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-77eda84191a2> in <module>()
# ----> 1 linReg.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(linReg.intercept_)

# %%
print(linReg.coef_)

# %%
y_pred = linReg.predict(x_test)

# %%
#x negative target
#y positive predict

# %%
cases_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-e9aba0b78151> in <module>()
# ----> 1 df_cases.shape
#
# NameError: name 'df_cases' is not defined

# %%
#Model Training
